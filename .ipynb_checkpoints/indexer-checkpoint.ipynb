# %% [markdown]
# # Indexer for Search Engine with Ranking

# %%
import pandas as pd

# %% [markdown]
# ## Import Websites from json file

# %%
websites = pd.read_json("data/table.json")
df = pd.DataFrame(websites)
df = df.reset_index()

# %% [markdown]
# ## Create new Dictionary to store website on database with following schema
#
# ```
# string: Website
# Website: {
#   url: string,
#   outgoingLinks: string[],
#   incomingLinks: string[]
# }
# ```

# %%
websites_dict = {}

for index, row in df.iterrows():
    url = row['url']
    if websites_dict.get(url) is None:
        websites_dict[url] = {
            "url": url,
            "outgoingLinks": list(set(row['metadata']['links'])),
            "outgoingLinksLen":len(row['metadata']['links']),
            "incomingLinks": [],
            "incomingLinksLen": 0 
        }

# %% [markdown]
# ## Assign Incoming Links to the created dictionary

# %%
for website in websites_dict:
    links = websites_dict[website]["outgoingLinks"]
    for link in links:
        linkInDict = websites_dict.get(link)
        if linkInDict is not None:
            websites_dict[link]["incomingLinks"].append(website)
            websites_dict[link]["incomingLinksLen"] = websites_dict[link]["incomingLinksLen"] + 1

website_pd = pd.DataFrame.from_dict(websites_dict)
website_pd.head(30)
# Out:
#                                                https://nepal.gov.np  \
# url                                            https://nepal.gov.np
# outgoingLinks     [https://nepal.gov.np:8443/NationalPortal/NP?s...
# outgoingLinksLen                                                  3
# incomingLinks                                                    []
# incomingLinksLen                                                  0
#
#                                                 https://moha.gov.np  \
# url                                             https://moha.gov.np
# outgoingLinks     [https://moha.gov.np/page/directive-framework,...
# outgoingLinksLen                                                114
# incomingLinks                                                    []
# incomingLinksLen                                                  0
#
#                                                   https://p1.gov.np  \
# url                                               https://p1.gov.np
# outgoingLinks     [https://moa.p1.gov.np/notice/general-notice/d...
# outgoingLinksLen                                                100
# incomingLinks                                                    []
# incomingLinksLen                                                  0
#
#                                                    http://p2.gov.np  \
# url                                                http://p2.gov.np
# outgoingLinks     [https://madhesh.gov.np/node/152, https://madh...
# outgoingLinksLen                                                 26
# incomingLinks                                                    []
# incomingLinksLen                                                  0
#
#                   http://p3.gov.np  http://p4.gov.np  http://p5.gov.np  \
# url               http://p3.gov.np  http://p4.gov.np  http://p5.gov.np
# outgoingLinks                   []                []                []
# outgoingLinksLen                 0                 0                 0
# incomingLinks                   []                []                []
# incomingLinksLen                 0                 0                 0
#
#                                                    http://p7.gov.np  \
# url                                                http://p7.gov.np
# outgoingLinks     [http://sudurpashchim.gov.np/#, http://sudurpa...
# outgoingLinksLen                                                 18
# incomingLinks                                                    []
# incomingLinksLen                                                  0
#
#                  https://nepal.gov.np:8443/NationalPortal/NP?splashAction=home  \
# url               https://nepal.gov.np:8443/NationalPortal/NP?sp...
# outgoingLinks     [https://nepalpassport.gov.np/, https://nepal....
# outgoingLinksLen                                                229
# incomingLinks     [https://nepal.gov.np, https://nepal.gov.np/, ...
# incomingLinksLen                                                 35
#
#                  https://nepal.gov.np:8443/NationalPortal/NP?splashAction=business  \
# url               https://nepal.gov.np:8443/NationalPortal/NP?sp...
# outgoingLinks     [https://nepalpassport.gov.np/, https://nepal....
# outgoingLinksLen                                                229
# incomingLinks     [https://nepal.gov.np, https://nepal.gov.np/, ...
# incomingLinksLen                                                 35
#
#                   ...                                 http://nsc.gov.np/  \
# url               ...                                 http://nsc.gov.np/
# outgoingLinks     ...  [https://nsc.gov.np/prizes-np/, https://nsc.go...
# outgoingLinksLen  ...                                                 43
# incomingLinks     ...  [https://nepal.gov.np:8443/NationalPortal/view...
# incomingLinksLen  ...                                                 14
#
#                                                  http://nic.gov.np/  \
# url                                              http://nic.gov.np/
# outgoingLinks     [https://nic.gov.np/faq, https://nic.gov.np/ca...
# outgoingLinksLen                                                 81
# incomingLinks     [https://nepal.gov.np:8443/NationalPortal/view...
# incomingLinksLen                                                 28
#
#                                              http://www.ocr.gov.np/  \
# url                                          http://www.ocr.gov.np/
# outgoingLinks     [https://www.ocr.gov.np/page/1_5e27366ad3cb4, ...
# outgoingLinksLen                                                 60
# incomingLinks     [https://nepal.gov.np:8443/NationalPortal/view...
# incomingLinksLen                                                 28
#
#                                             http://www.ppmo.gov.np/  \
# url                                         http://www.ppmo.gov.np/
# outgoingLinks     [https://ppmo.gov.np/acts_and_regulations, htt...
# outgoingLinksLen                                                 72
# incomingLinks     [https://nepal.gov.np:8443/NationalPortal/view...
# incomingLinksLen                                                 42
#
#                                              http://www.swc.org.np/  \
# url                                          http://www.swc.org.np/
# outgoingLinks     [http://www.swc.org.np/pages/450, https://swc....
# outgoingLinksLen                                                 72
# incomingLinks     [https://nepal.gov.np:8443/NationalPortal/view...
# incomingLinksLen                                                 21
#
#                                         http://www.ugcnepal.edu.np/  \
# url                                     http://www.ugcnepal.edu.np/
# outgoingLinks     [http://www.ugcnepal.edu.np/division/5, http:/...
# outgoingLinksLen                                                118
# incomingLinks     [https://nepal.gov.np:8443/NationalPortal/view...
# incomingLinksLen                                                 21
#
#                                             http://www.wecs.gov.np/  \
# url                                         http://www.wecs.gov.np/
# outgoingLinks     [http://www.wecs.gov.np/storage/listies/June20...
# outgoingLinksLen                                                 56
# incomingLinks     [https://nepal.gov.np:8443/NationalPortal/view...
# incomingLinksLen                                                 35
#
#                                              http://www.nmc.org.np/  \
# url                                          http://www.nmc.org.np/
# outgoingLinks     [https://nmc.org.np/news, https://exam.nmc.org...
# outgoingLinksLen                                                 33
# incomingLinks     [https://nepal.gov.np:8443/NationalPortal/view...
# incomingLinksLen                                                 14
#
#                                                 http://nhrc.gov.np/  \
# url                                             http://nhrc.gov.np/
# outgoingLinks     [https://nhrc.gov.np/publication-category/byla...
# outgoingLinksLen                                                 79
# incomingLinks     [https://nepal.gov.np:8443/NationalPortal/view...
# incomingLinksLen                                                 42
#
#                                               https://hib.gov.np/np
# url                                           https://hib.gov.np/np
# outgoingLinks     [https://hib.gov.np/pages/roles-functions-and-...
# outgoingLinksLen                                                 58
# incomingLinks     [https://nepal.gov.np:8443/NationalPortal/view...
# incomingLinksLen                                                 21
#
# [5 rows x 5277 columns]

# %% [markdown]
# ## Save Dictionary Data to JSON file

# %%
website_pd.to_json("websites.json")
