# %% [markdown]
# # Indexer for Search Engine with Ranking

# %%
import pandas as pd

# %% [markdown]
# ## Import Websites from json file

# %%
websites = pd.read_json("data/table.json")
df = pd.DataFrame(websites)
df = df.reset_index()
df.head(3)
# Out:
#    index  id                   url status  dispatchToken  \
# 0      0   1  https://nepal.gov.np   done            NaN
# 1      1   2   https://moha.gov.np   done            NaN
# 2      2   3     https://p1.gov.np   done            NaN
#
#                           contentHashId                 createdAt  \
# 0  ba422f11-88b3-43a2-bfe3-147cff6b6f24  2022-12-16T07:52:43.982Z
# 1  6e36b5ec-9419-46de-a4e6-b558beb14eb2  2022-12-16T07:52:44.042Z
# 2  d15807d0-5043-40b4-9465-18cd0517267f  2022-12-16T07:52:44.132Z
#
#                   updatedAt         dispatchAgent                 clientEnd  \
# 0  2022-12-16T07:56:11.957Z  kG_amT2-70kWc2XYAAAB  2022-12-16T07:56:11.535Z
# 1  2022-12-16T07:58:43.935Z  S_eXYDY_dk3-8euAAAAD  2022-12-16T07:58:37.772Z
# 2  2022-12-16T07:59:18.859Z  S_eXYDY_dk3-8euAAAAD  2022-12-16T07:59:13.435Z
#
#                 clientStart                 serverEnd  \
# 0  2022-12-16T07:55:55.985Z  2022-12-16T07:56:11.896Z
# 1  2022-12-16T07:58:12.905Z  2022-12-16T07:58:43.883Z
# 2  2022-12-16T07:58:44.037Z  2022-12-16T07:59:18.806Z
#
#                 serverStart                                           metadata
# 0  2022-12-16T07:55:55.982Z  {'url': 'https://nepal.gov.np', 'title': 'Nepa...
# 1  2022-12-16T07:58:12.903Z  {'url': 'https://moha.gov.np', 'title': 'गृह म...
# 2  2022-12-16T07:58:44.036Z  {'url': 'https://p1.gov.np', 'title': 'प्रदेश ...

# %% [markdown]
# ## Create new Dictionary to store website on database with following schema
#
# ```
# string: Website
# Website: {
#   url: string,
#   outgoingLinks: string[],
#   incomingLinks: string[]
# }
# ```

# %%
websites_dict = {}

for index, row in df.iterrows():
    url = row['url']
    if websites_dict.get(url) is None:
        websites_dict[url] = {
            "url": url,
            "outgoingLinks": list(set(row['metadata']['links'])),
            "outgoingLinksLen":len(row['metadata']['links']),
            "incomingLinks": [],
            "incomingLinksLen": 0,
            "contentHashId":row["contentHashId"]
        }

# %% [markdown]
# ## Assign Incoming Links to the created dictionary

# %%
for website in websites_dict:
    links = websites_dict[website]["outgoingLinks"]
    for link in links:
        linkInDict = websites_dict.get(link)
        if linkInDict is not None:
            if not website in websites_dict[link]["incomingLinks"]: 
                websites_dict[link]["incomingLinks"].append(website)
                websites_dict[link]["incomingLinksLen"] = websites_dict[link]["incomingLinksLen"] + 1
            
            

website_pd = pd.DataFrame.from_dict(websites_dict)
website_pd.head(30).T
# Out:
#                                                      url  \
# https://nepal.gov.np                https://nepal.gov.np
# https://moha.gov.np                  https://moha.gov.np
# https://p1.gov.np                      https://p1.gov.np
# http://p2.gov.np                        http://p2.gov.np
# http://p3.gov.np                        http://p3.gov.np
# ...                                                  ...
# http://www.ugcnepal.edu.np/  http://www.ugcnepal.edu.np/
# http://www.wecs.gov.np/          http://www.wecs.gov.np/
# http://www.nmc.org.np/            http://www.nmc.org.np/
# http://nhrc.gov.np/                  http://nhrc.gov.np/
# https://hib.gov.np/np              https://hib.gov.np/np
#
#                                                                  outgoingLinks  \
# https://nepal.gov.np         [https://nepal.gov.np:8443/NationalPortal/NP?s...
# https://moha.gov.np          [https://moha.gov.np/, https://moha.gov.np/gal...
# https://p1.gov.np            [https://p1.gov.np/detail/sewa-prava, https://...
# http://p2.gov.np             [https://madhesh.gov.np/node/155, https://madh...
# http://p3.gov.np                                                            []
# ...                                                                        ...
# http://www.ugcnepal.edu.np/  [http://www.ugcnepal.edu.np/downloads/1/5, htt...
# http://www.wecs.gov.np/      [http://www.wecs.gov.np/pages/documents, https...
# http://www.nmc.org.np/       [https://nmc.org.np/cpd-modules, https://nmc.o...
# http://nhrc.gov.np/          [https://nhrc.gov.np/trainings/training-worksh...
# https://hib.gov.np/np        [https://hib.gov.np/pages/karnali-province, ht...
#
#                             outgoingLinksLen  \
# https://nepal.gov.np                       3
# https://moha.gov.np                      114
# https://p1.gov.np                        100
# http://p2.gov.np                          26
# http://p3.gov.np                           0
# ...                                      ...
# http://www.ugcnepal.edu.np/              118
# http://www.wecs.gov.np/                   56
# http://www.nmc.org.np/                    33
# http://nhrc.gov.np/                       79
# https://hib.gov.np/np                     58
#
#                                                                  incomingLinks  \
# https://nepal.gov.np                                                        []
# https://moha.gov.np                                                         []
# https://p1.gov.np                                                           []
# http://p2.gov.np                                                            []
# http://p3.gov.np                                                            []
# ...                                                                        ...
# http://www.ugcnepal.edu.np/  [https://nepal.gov.np:8443/NationalPortal/view...
# http://www.wecs.gov.np/      [https://nepal.gov.np:8443/NationalPortal/view...
# http://www.nmc.org.np/       [https://nepal.gov.np:8443/NationalPortal/view...
# http://nhrc.gov.np/          [https://nepal.gov.np:8443/NationalPortal/view...
# https://hib.gov.np/np        [https://nepal.gov.np:8443/NationalPortal/view...
#
#                             incomingLinksLen  \
# https://nepal.gov.np                       0
# https://moha.gov.np                        0
# https://p1.gov.np                          0
# http://p2.gov.np                           0
# http://p3.gov.np                           0
# ...                                      ...
# http://www.ugcnepal.edu.np/                3
# http://www.wecs.gov.np/                    5
# http://www.nmc.org.np/                     2
# http://nhrc.gov.np/                        6
# https://hib.gov.np/np                      3
#
#                                                     contentHashId
# https://nepal.gov.np         ba422f11-88b3-43a2-bfe3-147cff6b6f24
# https://moha.gov.np          6e36b5ec-9419-46de-a4e6-b558beb14eb2
# https://p1.gov.np            d15807d0-5043-40b4-9465-18cd0517267f
# http://p2.gov.np             897de6d0-342a-4ed1-9b36-3265340e1705
# http://p3.gov.np             2015b910-06c8-428d-a35f-c6f3427401b3
# ...                                                           ...
# http://www.ugcnepal.edu.np/  27100abd-fabc-438a-9c84-615d232cfec8
# http://www.wecs.gov.np/      0f174b39-ac03-4bcc-a1f3-2207dd2648d7
# http://www.nmc.org.np/       f3f47701-3233-4bc5-9ed1-9b4efb92f081
# http://nhrc.gov.np/          1e182a96-a375-4c1e-90b6-0fc2f053d256
# https://hib.gov.np/np        513786d1-b8a3-41f0-89a4-17c9100a2ab3
#
# [5277 rows x 6 columns]

# %% [markdown]
# ## Save Dictionary Data to JSON file

# %%
    website_pd.to_json("websites.json")

# %% [markdown]
# # Create List of Websites from dictionary

# %%
websites_list = list(websites_dict.values())
websites_list[2]
# Out:
# {'url': 'https://p1.gov.np',
#  'outgoingLinks': ['https://p1.gov.np/detail/sewa-prava',
#   'https://mowsie.p1.gov.np/notice/procurement-notice/detail/2079-01-5-supply-delivery-of-tubular-steel-electric-pole-copper-wound-distribution-of-outdoor-transformer-and-acsr-conductor-2079-01-05',
#   'http://motmc.p1.gov.np/',
#   'https://p1.gov.np/web/sidelink/mantralaya',
#   'https://p1.gov.np/report/yearly-report',
#   'https://p1.gov.np/detail/suchana',
#   'https://p1.gov.np/mantralaya/15',
#   'https://p1.gov.np/language/ne',
#   'https://motc.p1.gov.np/document/act_rule/detail/2079-08-28-95737',
#   'https://p1.gov.np/facebook.com',
#   'http://mowsie.p1.gov.np/notice/general-notice/detail/2079-08-21-69475',
#   'https://p1.gov.np/mantralaya/5',
#   'https://moh.p1.gov.np/report/yearly-report/detail/2079-07-29-46829',
#   'https://p1.gov.np/mantralaya/4',
#   'https://p1.gov.np/niti/directory',
#   'https://p1.gov.np/web/sidelink/e-services',
#   'https://p1.gov.np/mantralaya/11',
#   'https://moa.p1.gov.np/document/act/detail/2079-08-09-38116',
#   'https://p1.gov.np/notice/kharid-suchana',
#   'https://motc.p1.gov.np/document/nirdeshika/detail/2079-08-29-79368',
#   'https://mofelc.p1.gov.np/document/nirdeshika/detail/2079-07-25-76620',
#   'https://mowsie.p1.gov.np/notice/general-notice/detail/2079-08-12-21673',
#   'https://p1.gov.np/mantralaya/7',
#   'http://mofesc.p1.gov.np/',
#   'https://p1.gov.np/notice/covid-19-notice',
#   'https://moh.p1.gov.np/report/quaterly-report/detail/2079-06-05-26740',
#   'https://moa.p1.gov.np/document/act/detail/2079-08-09-80673',
#   'https://moh.p1.gov.np/report/yearly-report/detail/2079-08-23-24720',
#   'https://p1.gov.np/#',
#   'https://moh.p1.gov.np/',
#   'https://p1.gov.np/detail/prativedan',
#   'https://molmcpa.p1.gov.np/',
#   'http://mowsie.p1.gov.np/notice/general-notice/detail/2079-08-25-76581',
#   'https://cao.p1.gov.np/',
#   'https://p1.gov.np/detail/e-farum',
#   'https://p1.gov.np/mantralaya/1',
#   'https://motc.p1.gov.np/document/act_rule/detail/2079-08-28-74784',
#   'https://p1.gov.np/web/sidelink/important-place',
#   'https://ocmcm.p1.gov.np/',
#   'https://p1.gov.np/detail/procedure',
#   'https://moa.p1.gov.np/notice/general-notice/detail/2079-08-27-32163',
#   'http://mowsie.p1.gov.np/notice/general-notice/detail/2079-08-29-12181',
#   'http://mowsie.p1.gov.np/',
#   'https://moh.p1.gov.np/report/quaterly-report/detail/2079-08-20-56984',
#   'https://p1.gov.np/',
#   'https://p1.gov.np/detail/publication',
#   'https://moa.p1.gov.np/document/act/detail/2079-08-09-22775',
#   'https://p1.gov.np/mantralaya/16',
#   'https://mowsie.p1.gov.np/report/quaterly-report/detail/-.-.--2078-12-23',
#   'https://p1.gov.np/niti/nirdesika',
#   'https://p1.gov.np/web/sidelink/mantriparishad',
#   'https://p1.gov.np/bivagh-karyalaya',
#   'https://p1.gov.np/mantralaya/13',
#   'https://p1.gov.np/web/sidelink/hello-cm',
#   'https://p1.gov.np/report/taemasikh',
#   'https://p1.gov.np/#top',
#   'https://p1.gov.np/detail/yearly-budget',
#   'https://moile.p1.gov.np/',
#   'https://moa.p1.gov.np/document/act/detail/2079-08-09-33147',
#   'https://p1.gov.np/mantralaya/9',
#   'https://p1.gov.np/twitter.com',
#   'https://moa.p1.gov.np/notice/general-notice/detail/2079-09-01-87539',
#   'https://mowsie.p1.gov.np/notice/procurement-notice/detail/---2078-12-25',
#   'https://moa.p1.gov.np/document/act/detail/2079-08-09-89457',
#   'https://p1.gov.np/detail/kharid-bolpatra',
#   'https://p1.gov.np/detail/ain-kanoon',
#   'http://moial.p1.gov.np/',
#   'https://mowsie.p1.gov.np/notice/procurement-notice/detail/2079-04-26-97642',
#   'https://mofelc.p1.gov.np/document/nirdeshika/detail/2079-07-25-26269',
#   'https://p1.gov.np/niti/ayan',
#   'https://moa.p1.gov.np/',
#   'https://p1.gov.np/mantralaya/17',
#   'https://p1.gov.np/notice/sadaran-suchana',
#   'https://p1.gov.np/web/sidelink/karyalaya-pramukh',
#   'https://moriud.p1.gov.np/',
#   'http://mosd.p1.gov.np/',
#   'https://p1.gov.np/language/en',
#   'https://p1.gov.np/web/sidelink/pradeshsabhasadasya',
#   'https://p1.gov.np/mantralaya/14',
#   'https://p1.gov.np/mantralaya/18',
#   'https://p1.gov.np/mantralaya/10',
#   'https://p1.gov.np/mantralaya/3',
#   'https://p1.gov.np/mantralaya',
#   'https://p1.gov.np/web/sidelink/pradesh-sarkar',
#   'http://moeap.p1.gov.np/',
#   'https://p1.gov.np/mantralaya/20',
#   'http://oph.p1.gov.np/',
#   'https://motc.p1.gov.np/notice/general-notice/detail/2079-08-07-21436',
#   'https://assembly.p1.gov.np/',
#   'https://moa.p1.gov.np/notice/general-notice/detail/2079-09-01-13928',
#   'https://gis.p1.gov.np/',
#   'https://p1.gov.np/web/sidelink/sthaniya-taha',
#   'https://mowsie.p1.gov.np/notice/general-notice/detail/2079-08-13-13834',
#   'https://moa.p1.gov.np/notice/general-notice/detail/2079-09-01-84254',
#   'https://moa.p1.gov.np/notice/general-notice/detail/2079-08-28-65117',
#   'https://motc.p1.gov.np/notice/general-notice/detail/2079-09-01-85381',
#   'https://mowsie.p1.gov.np/notice/general-notice/detail/2079-08-13-10678',
#   'https://p1.gov.np/mantralaya/8',
#   'https://motc.p1.gov.np/',
#   'https://p1.gov.np/mantralaya/19'],
#  'outgoingLinksLen': 100,
#  'incomingLinks': [],
#  'incomingLinksLen': 0,
#  'contentHashId': 'd15807d0-5043-40b4-9465-18cd0517267f'}

# %% [markdown]
# ## Save Dictionary Data to MongoDB

# %% [markdown]
# ### Initialize pymongo

# %%
import pymongo as pm
mongouri = "mongodb://root:prisma@localhost:27017/db_seven_sem_prj?authSource=admin"
client = pm.MongoClient(mongouri)
database = client.get_database()
print(database)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin'), 'db_seven_sem_prj')

# %%
website_collection = database['websites']

# %%
website_collection.insert_many(websites_list)

# %% [markdown]
# # Verify Data Inserted by showing the total rows in database

# %%
websites_in_db = database["websites"].find()
print(list(websites_in_db)[0])
# Out:
# {'_id': ObjectId('63da9e91df832131f59f8727'), 'url': 'https://nepal.gov.np', 'outgoingLinks': ['https://nepal.gov.np:8443/NationalPortal/NP?splashAction=home', 'https://nepal.gov.np:8443/NationalPortal/NP?splashAction=business', 'https://nepal.gov.np:8443/NationalPortal/NP?splashAction=citizen'], 'outgoingLinksLen': 3, 'incomingLinks': [], 'incomingLinksLen': 0, 'contentHashId': 'ba422f11-88b3-43a2-bfe3-147cff6b6f24'}

# %% [markdown]
# # For each website, get text data from folder whose name is in contentHashId

# %% [markdown]
# ## Testing for only one website
